# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivaramkarthik/ML_24AG5A6618/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("enter the number :"))
a=a**0.5
if a%1==0:
 print ("perfect squre")
else :
   print("not perfect squre")]
# Out:
# enter the number :121
# perfect squre

# %%
import time
import sys
h=3
m=40
s=0
while True:
  sys.stdout.write("\r%02d:%02d:%02d" % (h,m,s))

# %%
a= input("enter string  posword" )
lp=0
sp=0
num=0
up=0
if i in a.islower():
  lp=lp+1

# %%
from datetime import datetime
import pytz
a=pytz.timezone("Asia/Tokyo")
b=datetime.now(a)
print(b)
for i in pytz.all_timezones:
  print(i)
# Out:
# 2026-04-29 19:29:21.225938+09:00
# Africa/Abidjan
# Africa/Accra
# Africa/Addis_Ababa
# Africa/Algiers
# Africa/Asmara
# Africa/Asmera
# Africa/Bamako
# Africa/Bangui
# Africa/Banjul
# Africa/Bissau
# Africa/Blantyre
# Africa/Brazzaville
# Africa/Bujumbura
# Africa/Cairo
# Africa/Casablanca
# Africa/Ceuta
# Africa/Conakry
# Africa/Dakar
# Africa/Dar_es_Salaam
# Africa/Djibouti
# Africa/Douala
# Africa/El_Aaiun
# Africa/Freetown
# Africa/Gaborone
# Africa/Harare
# Africa/Johannesburg
# Africa/Juba
# Africa/Kampala
# Africa/Khartoum
# Africa/Kigali
# Africa/Kinshasa
# Africa/Lagos
# Africa/Libreville
# Africa/Lome
# Africa/Luanda
# Africa/Lubumbashi
# Africa/Lusaka
# Africa/Malabo
# Africa/Maputo
# Africa/Maseru
# Africa/Mbabane
# Africa/Mogadishu
# Africa/Monrovia
# Africa/Nairobi
# Africa/Ndjamena
# Africa/Niamey
# Africa/Nouakchott
# Africa/Ouagadougou
# Africa/Porto-Novo
# Africa/Sao_Tome
# Africa/Timbuktu
# Africa/Tripoli
# Africa/Tunis
# Africa/Windhoek
# America/Adak
# ...

# %%
a=[chr(i)for i in range (65,91) if chr(i) not in 'AEIOU']
print (a)
# Out:
# ['B', 'C', 'D', 'F', 'G', 'H', 'J', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'X', 'Y', 'Z']

# %%
name=["a","s","d","f","k"]
marks=[[1,3,4],[5,2,2],[1,3,3],[1,3,4],[1,3,4]]
for i in range(len(name)):

  print(f"{name[i]}={marks[i]}")
# Out:
# a=[1, 3, 4]
# s=[5, 2, 2]
# d=[1, 3, 3]
# f=[1, 3, 4]
# k=[1, 3, 4]

# %%
name=["Chota bheem","Raju","Shiva","Jaggu","Indrani","Bobby"]
marks=[[45,78,90],[65,66,67],[70,72,71],[54,56,58],[66,66,67],[98,99,98]]
for i in range (len(name)):
  a=(marks[i][0]+marks[i][1]+marks[i][2])/300
  a=int(a*100)
  if a>90:
    g="s"
  if a<90 and a>60:
    g="a"
  if a>40 and a<60:
    g="b"
  if a <40:
    g="f"
  print(f"{name[i]} has scored {a}% and grade is {g}")
# Out:
# Chota bheem has scored 71% and grade is a
# Raju has scored 66% and grade is a
# Shiva has scored 71% and grade is a
# Jaggu has scored 56% and grade is b
# Indrani has scored 66% and grade is a
# Bobby has scored 98% and grade is s

# %%
name=["Chota bheem","Raju","Shiva","Jaggu","Indrani","Bobby"]
marks=[55,78,90,65,66,67]
res= list(zip(marks,name))
res1=sorted(res)
p=0
for i in range(5):
  p=p+1
  print(f"rank postion is {p}  name is  {res1[i][0]}   and age is {res1[i][1]}")
# Out:
# rank postion is 1  name is  55   and age is Chota bheem
# rank postion is 2  name is  65   and age is Jaggu
# rank postion is 3  name is  66   and age is Indrani
# rank postion is 4  name is  67   and age is Bobby
# rank postion is 5  name is  78   and age is Raju

# %%
x="AAACCDDDAADD"
res=""
c=1
for i in range(len(x)-1):
  if x[i]==x[i+1] and i+1<len(x):
    c=c+1
  else:
    res=res+x[i]+str(c)
    c=c+1
print(res)
# Out:
# A3C5D8A10

# %%
def flower(a):
  if a == 4:
    return
  print (a+10,end=" ")
  flower(a+1)
  print(a,end=" ")
flower(1)
# Out:
# 11 12 13 3 2 1

# %%
def raju(a):
  if a==1:
    return
  a-=1
  raju(a)

  print("Hai")
  raju(a)
raju(4)
# Out:
# Hai
# Hai
# Hai
# Hai
# Hai
# Hai
# Hai

# %%
def karthik(a):
  if a==1:
    return
  i=2
  while(a%i !=0):
    i=i+1
  print (i,end=" ")
  karthik(a/i)
a=int(input())
karthik(a)
# Out:
# 100
# 2 2 5 5
